# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from datetime import datetime
import seaborn as sns

# %%
df = pd.read_csv('C:\\Users\\Sabbir Ahmed\\Downloads\\disney_plus_titles.csv')

# %%
df.head(10)
# Out:
#   show_id     type                                              title  \
# 0      s1    Movie                                      A Spark Story
# 1      s2    Movie                                     Spooky Buddies
# 2      s3    Movie                             The Fault in Our Stars
# 3      s4  TV Show                                    Dog: Impossible
# 4      s5  TV Show                     Spidey And His Amazing Friends
# 5      s6  TV Show                                 Star Wars: Visions
# 6      s7    Movie                        Confessions of a Shopaholic
# 7      s8    Movie                         Descendants: Royal Wedding
# 8      s9    Movie  Disney's Broadway Hits at London's Royal Alber...
# 9     s10    Movie                          Flooded Tombs of the Nile
#
#                      director  \
# 0  Jason Sterman, Leanne Dare
# 1                Robert Vince
# 2                  Josh Boone
# 3                         NaN
# 4                         NaN
# ...

# %%
df.tail(7)
# Out:
#      show_id     type                      title  \
# 1361   s1362    Movie   The Cat from Outer Space
# 1362   s1363    Movie  The Great Mouse Detective
# 1363   s1364    Movie     The Sword in the Stone
# 1364   s1365    Movie            Those Calloways
# 1365   s1366  TV Show       Disney Kirby Buckets
# 1366   s1367  TV Show             Disney Mech-X4
# 1367   s1368  TV Show         Imagination Movers
#
#                                       director  \
# 1361                              Norman Tokar
# 1362  John Musker, Ron Clements, Dave Michener
# 1363                       Wolfgang Reitherman
# 1364                              Norman Tokar
# 1365                                       NaN
# 1366                                       NaN
# 1367                                       NaN
#
#                                                    cast        country  \
# 1361  Ken Berry, Sandy Duncan, Harry Morgan, Roddy M...  United States
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1368 entries, 0 to 1367
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   show_id       1368 non-null   object
#  1   type          1368 non-null   object
#  2   title         1368 non-null   object
#  3   director      928 non-null    object
#  4   cast          1194 non-null   object
#  5   country       1193 non-null   object
#  6   date_added    1365 non-null   object
#  7   release_year  1368 non-null   int64
#  8   rating        1366 non-null   object
#  9   duration      1368 non-null   object
#  10  listed_in     1368 non-null   object
#  11  description   1368 non-null   object
# dtypes: int64(1), object(11)
# memory usage: 128.4+ KB

# %%
print(df.shape)
# Out:
# (1368, 12)

# %%
print(df.dtypes.value_counts())
# Out:
# object    11
# int64      1
# dtype: int64

# %%
print('The columns in the data are ', df.columns)
# Out:
# The columns in the data are  Index(['show_id', 'type', 'title', 'director', 'cast', 'country', 'date_added',
#        'release_year', 'rating', 'duration', 'listed_in', 'description'],
#       dtype='object')

# %%
#Checking for duplicate values
df.duplicated().sum()
# Out:
# 0

# %%
#Checking for missing values and their count
null_values=df.isnull().sum() 
null_values=null_values[null_values>0]
null_values_df=pd.DataFrame(null_values, columns=['null_values'])
null_values_df
# Out:
#             null_values
# director            440
# cast                174
# country             175
# date_added            3
# rating                2

# %%
#summary statistics
df.describe()[1:].T.sort_index().style.background_gradient(cmap='GnBu', axis=1)
# Out:
# <style type="text/css">
# #T_d203f_row0_col0, #T_d203f_row0_col3 {
#   background-color: #084384;
#   color: #f1f1f1;
# }
# #T_d203f_row0_col1 {
#   background-color: #f7fcf0;
#   color: #000000;
# }
# #T_d203f_row0_col2 {
#   background-color: #084e90;
#   color: #f1f1f1;
# }
# #T_d203f_row0_col4 {
#   background-color: #084182;
#   color: #f1f1f1;
# }
# #T_d203f_row0_col5, #T_d203f_row0_col6 {
#   background-color: #084081;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_d203f">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_d203f_level0_col0" class="col_heading level0 col0" >mean</th>
#       <th id="T_d203f_level0_col1" class="col_heading level0 col1" >std</th>
#       <th id="T_d203f_level0_col2" class="col_heading level0 col2" >min</th>
#       <th id="T_d203f_level0_col3" class="col_heading level0 col3" >25%</th>
#       <th id="T_d203f_level0_col4" class="col_heading level0 col4" >50%</th>
# ...

# %%
# Assuming there is a 'date_added' column in the dataset
df['date_added'] = pd.to_datetime(df['date_added'])

# Set 'date_added' as the index
df.set_index('date_added', inplace=True)

# Resample the data by month and count the number of titles added
monthly_data = df['title'].resample('M').count()

# Plot the time series data
plt.figure(figsize=(12, 6))
sns.lineplot(data=monthly_data)
plt.title('Monthly Count of Titles Added')
plt.xlabel('Date')
plt.ylabel('Number of Titles Added')
plt.show()

# %%
plt.figure(figsize=(12, 6))
sns.histplot(df['duration'], kde=True)
plt.xlabel('duration')
plt.ylabel('Frequency')
plt.show()

# %%
df['type'].value_counts().plot(kind='bar',color=['yellow','green'])
plt.title('distribution of titles of types ')
plt.xlabel('Type')
plt.ylabel('count')
plt.show()

# %%
df['rating'].value_counts().plot(kind='bar',color=['yellow','green','red','orange'])
plt.title('distribution of titles  by rating')
plt.xlabel('rating')
plt.ylabel('count')
plt.show()

# %%
df['release_year'].value_counts().sort_index().plot(kind='bar',figsize=(15,5),color=['yellow','green','red','orange'])
plt.title('distribution of titles  by release year')
plt.xlabel('release Year')
plt.ylabel('count')
plt.show()
